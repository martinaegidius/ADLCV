# %%
import torch 
import matplotlib.pyplot as plt
import numpy as np 

train_loss = torch.load("train_loss.pt")
plt.plot(train_loss)

# %%
#cosine results
fig, ax = plt.subplots(2,3,figsize=(20,15))
cos_res = [plt.imread("cosine/1.jpg"),plt.imread("cosine/10.jpg"),plt.imread("cosine/29.jpg")]
lin_res = [plt.imread("linear/1.jpg"),plt.imread("linear/10.jpg"),plt.imread("linear/30.jpg")]

for i, im in enumerate(cos_res):
    ax[0,i].imshow(im)
    ax[1,i].imshow(lin_res[i])
